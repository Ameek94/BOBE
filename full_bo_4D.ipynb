# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from fb_gp import saas_fbgp
import numpy as np
import time
import jax.numpy as jnp
from jax import random,vmap, grad
from jax.lax import while_loop
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from acquisition import EI, IPV, optim_scipy_bh
import scipy.optimize
from scipy.stats import qmc
from jaxns import NestedSampler
import corner
from nested_sampler import nested_sampling_jaxns, nested_sampling_Dy
from getdist import plots,MCSamples,loadMCSamples


matplotlib.rc('font', size=16,family='serif')
matplotlib.rc('legend', fontsize=16)
# Out:
# INFO:jax._src.xla_bridge:Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO:jax._src.xla_bridge:Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/homebrew/Caskroom/miniforge/base/envs/cosmo/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file), '/usr/local/lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache)

# %% [markdown]
# ### EI test

# %%
np.random.seed(10004118) # fixed for reproducibility
# train_x = np.random.uniform(0,1,(12,2))
ninit = 16
ndim = 4
train_x = qmc.Sobol(ndim, scramble=True).random(ninit)
f_mean = np.array([0.41,0.63,0.58,0.45])[:ndim]
cov1 = 0.1*np.eye(ndim) + 0.2*np.random.uniform(0.,0.5,(ndim,ndim))
cov = 0.05*(cov1 + np.transpose(cov1))
print(cov)

from scipy.stats import multivariate_normal

mnorm =  multivariate_normal(mean = f_mean,cov = cov)

f = lambda x: mnorm.logpdf(x).reshape(-1,1) # -0.5*np.sum((x - f_mean)**2,axis=-1,keepdims=True)/ f_std**2 

train_y = f(train_x)
print(train_x.shape,train_y.shape)

train_yvar = 1e-6*jnp.ones_like(train_y)

print("Testing lightweight implementation")

gp = saas_fbgp(train_x,train_y,noise=1e-6)
seed = 0
rng_key, _ = random.split(random.PRNGKey(seed), 2)
gp.fit(rng_key,warmup_steps=512,num_samples=512,thinning=16,verbose=True)

fig,(ax1,ax2) = plt.subplots(1,2,figsize=(12,4))
ax1.scatter(train_x[:,0],train_x[:,1])
ax1.set_xlabel(r'$x_1$')
ax1.set_ylabel(r'$x_2$')
ax2.scatter(train_x[:,2],train_x[:,3])
ax2.set_xlabel(r'$x_3$')
ax2.set_ylabel(r'$x_4$')
# Out:
# [[0.01795472 0.0032797  0.00629377 0.00188088]
#  [0.0032797  0.01140048 0.00206096 0.00450058]
#  [0.00629377 0.00206096 0.0193845  0.00201846]
#  [0.00188088 0.00450058 0.00201846 0.01147207]]
# (16, 4) (16, 1)
# Testing lightweight implementation
# sample: 100%|██████████| 1024/1024 [00:01<00:00, 972.96it/s, 7 steps of size 3.75e-01. acc. prob=0.90]
#                               mean       std    median      5.0%     95.0%     n_eff     r_hat
# _kernel_inv_length_sq[0]      3.53      7.93      1.01      0.06      4.79     39.32      1.01
# _kernel_inv_length_sq[1]     37.81    135.90      3.15      0.57     22.04     35.56      0.98
# _kernel_inv_length_sq[2]      2.00      1.78      1.60      0.21      4.07     26.62      1.00
# _kernel_inv_length_sq[3]      5.35     11.21      1.92      0.16     11.05     22.76      1.02
#         kernel_length[0]      1.09      1.28      0.64      0.09      3.03     24.33      1.00
#         kernel_length[1]      0.40      0.24      0.39      0.06      0.67     38.52      0.97
#         kernel_length[2]      0.70      0.42      0.55      0.11      1.25     21.34      0.99
#         kernel_length[3]      0.68      0.80      0.50      0.07      0.87     46.91      0.98
#             kernel_tausq      5.22      9.05      1.82      0.25     11.69     40.16      0.98
#               kernel_var      4.05      3.21      2.73      0.72      8.79     53.46      0.99
#
# Number of divergences: 0
#
# MCMC elapsed time: 1.51s
# Text(0, 0.5, '$x_4$')

# %%
nsteps = 16 # 32
mc_points_size = 16
start = time.time()
for i in range(nsteps):
    samples, logz_dict = samples, logz_dict = nested_sampling_jaxns(gp,ndim=ndim,dlogz=0.1)
    print(f"LogZ info :"+"".join(f"{key}: = {value:.4f}, " for key, value in logz_dict.items()))
    size = len(samples)
    mc_points = samples[::int(size/mc_points_size),:]
    acq_func = EI(gp,gp.train_y.max()) # IPV(gp,mc_points)
    grad_fn = grad(acq_func)
    # print(ndim)
    x0 =  np.random.uniform(0,1,ndim)
    # print(x0.shape)
    results = optim_scipy_bh(acq_func,x0=x0,stepsize=1/4,
                                      niter=15,minimizer_kwargs={'jac': grad_fn, 'bounds': ndim*[(0,1)] })
    # next_val = results.fun 
    print(f"Next point at x = {results.x} with acquisition function value = {results.fun}")
    next_x = jnp.atleast_2d(results.x)
    next_y = f((next_x)) 
    # print(next_y.shape)
    train_x = jnp.concatenate([train_x,next_x])
    train_y = jnp.concatenate([train_y,next_y])
    gp = saas_fbgp(train_x,train_y,noise=1e-6)
    gp.fit(rng_key,warmup_steps=256,num_samples=256,thinning=16,verbose=False) # change rng key?
    print(f"----------------------Step {i+1} complete----------------------\n")


print(f"BO took {time.time() - start:.2f} s ")
# Out:
# Nested Sampling took 1.96s
# jaxns made 23761 likelihood evaluations
# LogZ info :logz_mean: = -2.7070, dlogz: = 0.2607,
# Acquisition optimization took 2.60 s
# Next point at x = [0.         0.56553986 0.57518978 0.30400751] with acquisition function value = -0.30884787191527446
# sample: 100%|██████████| 512/512 [00:00<00:00, 544.13it/s, 31 steps of size 1.47e-01. acc. prob=0.92]
# MCMC elapsed time: 1.40s
# ----------------------Step 1 complete----------------------
#
# Nested Sampling took 1.91s
# jaxns made 30157 likelihood evaluations
# LogZ info :logz_mean: = -2.4738, dlogz: = 0.2603,
# Acquisition optimization took 3.31 s
# Next point at x = [0.40337703 0.61056966 0.57071986 0.47442845] with acquisition function value = -0.3428424432995737
# sample: 100%|██████████| 512/512 [00:00<00:00, 598.60it/s, 15 steps of size 3.48e-01. acc. prob=0.87]
# MCMC elapsed time: 1.30s
# ----------------------Step 2 complete----------------------
#
# Nested Sampling took 2.21s
# jaxns made 30383 likelihood evaluations
# LogZ info :logz_mean: = -1.4345, dlogz: = 0.2679,
# Acquisition optimization took 3.43 s
# Next point at x = [0.61688807 0.75718067 1.         0.61001556] with acquisition function value = -0.08323956972004981
# sample: 100%|██████████| 512/512 [00:00<00:00, 614.91it/s, 7 steps of size 4.57e-01. acc. prob=0.88]
# MCMC elapsed time: 1.28s
# ----------------------Step 3 complete----------------------
#
# Nested Sampling took 2.58s
# jaxns made 33176 likelihood evaluations
# LogZ info :logz_mean: = -0.4794, dlogz: = 0.2603,
# Acquisition optimization took 1.22 s
# Next point at x = [0. 0. 1. 0.] with acquisition function value = -0.03567802854930441
# sample: 100%|██████████| 512/512 [00:00<00:00, 595.54it/s, 7 steps of size 3.58e-01. acc. prob=0.91]
# MCMC elapsed time: 1.31s
# ----------------------Step 4 complete----------------------
#
# Nested Sampling took 1.97s
# jaxns made 28466 likelihood evaluations
# LogZ info :logz_mean: = -0.2218, dlogz: = 0.2687,
# Acquisition optimization took 2.03 s
# Next point at x = [0.         1.         0.         0.51399964] with acquisition function value = -0.005629523872872788
# sample: 100%|██████████| 512/512 [00:00<00:00, 591.95it/s, 7 steps of size 4.32e-01. acc. prob=0.91]
# MCMC elapsed time: 1.33s
# ----------------------Step 5 complete----------------------
#
# Nested Sampling took 2.03s
# jaxns made 28395 likelihood evaluations
# LogZ info :logz_mean: = -0.5462, dlogz: = 0.2710,
# Acquisition optimization took 3.46 s
# Next point at x = [0.38374741 0.70885597 0.69216    0.47279706] with acquisition function value = -0.02090410131060311
# sample: 100%|██████████| 512/512 [00:00<00:00, 614.06it/s, 7 steps of size 6.23e-01. acc. prob=0.90]
# MCMC elapsed time: 1.30s
# ----------------------Step 6 complete----------------------
#
# Nested Sampling took 2.05s
# jaxns made 29666 likelihood evaluations
# LogZ info :logz_mean: = -0.0056, dlogz: = 0.2664,
# Acquisition optimization took 1.59 s
# Next point at x = [0. 0. 0. 0.] with acquisition function value = -0.006532823030704415
# sample: 100%|██████████| 512/512 [00:00<00:00, 605.60it/s, 7 steps of size 5.69e-01. acc. prob=0.91]
# MCMC elapsed time: 1.30s
# ----------------------Step 7 complete----------------------
#
# Nested Sampling took 2.07s
# jaxns made 27924 likelihood evaluations
# LogZ info :logz_mean: = -0.2778, dlogz: = 0.2733,
# Acquisition optimization took 2.31 s
# Next point at x = [1.         1.         0.94086087 1.        ] with acquisition function value = -0.009258591193685344
# sample: 100%|██████████| 512/512 [00:00<00:00, 596.62it/s, 7 steps of size 6.11e-01. acc. prob=0.88]
# MCMC elapsed time: 1.32s
# ----------------------Step 8 complete----------------------
#
# Nested Sampling took 2.09s
# jaxns made 29096 likelihood evaluations
# LogZ info :logz_mean: = -0.0289, dlogz: = 0.2635,
# Acquisition optimization took 0.57 s
# Next point at x = [1.         0.29846902 0.78960712 0.78792704] with acquisition function value = -7.40646699666792e-10
# sample: 100%|██████████| 512/512 [00:00<00:00, 520.29it/s, 7 steps of size 4.83e-01. acc. prob=0.93]
# MCMC elapsed time: 1.50s
# ----------------------Step 9 complete----------------------
#
# Nested Sampling took 2.32s
# jaxns made 28286 likelihood evaluations
# LogZ info :logz_mean: = 0.0537, dlogz: = 0.2562,
# Acquisition optimization took 0.57 s
# Next point at x = [0.50609901 0.64582961 0.5576946  0.58852273] with acquisition function value = -6.317967285401536e-11
# sample: 100%|██████████| 512/512 [00:00<00:00, 582.45it/s, 7 steps of size 5.85e-01. acc. prob=0.93]
# MCMC elapsed time: 1.38s
# ----------------------Step 10 complete----------------------
#
# Nested Sampling took 2.16s
# jaxns made 29368 likelihood evaluations
# LogZ info :logz_mean: = -0.1002, dlogz: = 0.2606,
# Acquisition optimization took 0.60 s
# Next point at x = [0.77320814 1.         0.93405817 0.65812983] with acquisition function value = -1.8327503835456542e-08
# sample: 100%|██████████| 512/512 [00:00<00:00, 568.41it/s, 7 steps of size 6.67e-01. acc. prob=0.87]
# MCMC elapsed time: 1.40s
# ----------------------Step 11 complete----------------------
#
# Nested Sampling took 2.23s
# jaxns made 28913 likelihood evaluations
# LogZ info :logz_mean: = -0.0494, dlogz: = 0.2618,
# Acquisition optimization took 0.57 s
# Next point at x = [1.         0.70067344 0.20333257 1.        ] with acquisition function value = -1.0055119004155997e-42
# sample: 100%|██████████| 512/512 [00:00<00:00, 593.70it/s, 7 steps of size 6.18e-01. acc. prob=0.88]
# MCMC elapsed time: 1.35s
# ----------------------Step 12 complete----------------------
#
# Nested Sampling took 2.76s
# jaxns made 27591 likelihood evaluations
# LogZ info :logz_mean: = -0.1193, dlogz: = 0.2603,
# Acquisition optimization took 0.60 s
# Next point at x = [9.00050943e-01 6.24370229e-01 2.44839463e-04 0.00000000e+00] with acquisition function value = -1.0272162585573083e-19
# sample: 100%|██████████| 512/512 [00:00<00:00, 578.10it/s, 7 steps of size 5.87e-01. acc. prob=0.91]
# MCMC elapsed time: 1.42s
# ----------------------Step 13 complete----------------------
#
# Nested Sampling took 2.28s
# jaxns made 25277 likelihood evaluations
# LogZ info :logz_mean: = 0.0090, dlogz: = 0.2593,
# Acquisition optimization took 0.59 s
# Next point at x = [0.         0.69462087 1.         0.52110161] with acquisition function value = -1.965009184691418e-20
# sample: 100%|██████████| 512/512 [00:00<00:00, 564.60it/s, 7 steps of size 5.89e-01. acc. prob=0.91]
# MCMC elapsed time: 1.42s
# ----------------------Step 14 complete----------------------
#
# Nested Sampling took 2.35s
# jaxns made 28173 likelihood evaluations
# LogZ info :logz_mean: = -0.0675, dlogz: = 0.2629,
# Acquisition optimization took 0.63 s
# Next point at x = [0.62378161 0.         0.53405952 0.41424369] with acquisition function value = -6.590081149234077e-61
# sample: 100%|██████████| 512/512 [00:00<00:00, 534.84it/s, 7 steps of size 7.12e-01. acc. prob=0.86]
# MCMC elapsed time: 1.46s
# ----------------------Step 15 complete----------------------
#
# Nested Sampling took 2.38s
# jaxns made 25451 likelihood evaluations
# LogZ info :logz_mean: = 0.1188, dlogz: = 0.2586,
# Acquisition optimization took 0.66 s
# Next point at x = [0.         0.37570456 0.78639787 0.        ] with acquisition function value = -2.7934478888368156e-17
# sample: 100%|██████████| 512/512 [00:01<00:00, 272.03it/s, 7 steps of size 6.15e-01. acc. prob=0.91]
# MCMC elapsed time: 2.35s
# ----------------------Step 16 complete----------------------
#
# BO took 92.24 s

# %%
fig,ax = plt.subplots(1,int(ndim/2),figsize=(15,4))
for i,x in enumerate(ax):
    x.scatter(samples[:,2*i],samples[:,2*i+1],s=10,label='MC samples',color='C1',alpha=0.2)
    x.scatter(train_x[ninit:,2*i],train_x[ninit:,2*i+1],s=25,label='Bayop samples',color='C0')
    x.scatter(train_x[:ninit,2*i],train_x[:ninit,2*i+1],s=20,label='Sobol',color='C2')
    x.set_ylabel(r'$x_{{%i}}$'%(2*i+2))
    x.set_xlabel(r'$x_{{{}}}$'.format(2*i+1))
    x.axvline(f_mean[2*i],ls='-.',color='k')
    x.axhline(f_mean[2*i + 1],ls='-.',color='k')
ax[0].legend()

# %%
samples, logz_dict = nested_sampling_jaxns(gp,ndim=ndim,dlogz=0.01,num_samples_equal=3000,difficult_model=True)
print(f"LogZ "+"".join(f"{key}: {value:.4f}, " for key, value in logz_dict.items()))
# Out:
# Nested Sampling took 5.80s
# jaxns made 391571 likelihood evaluations
# LogZ logz_mean: -0.0098, dlogz: 0.1459,

# %%
test_samples = np.random.multivariate_normal(mean=f_mean,cov=cov,size=int(1e5))
labels = [r"x_{0}".format(i) for i in range(ndim)]
names = [r"x_{0}".format(i) for i in range(ndim)]
ranges =  np.array(ndim*[[0,1]])
true_samples = MCSamples(samples=test_samples,names=names, labels = labels,ranges=ranges) # a comparison run
gp_samples = MCSamples(samples=samples[::4],names=names, labels = labels,ranges=ranges)
g = plots.get_subplot_plotter(subplot_size=1.5,subplot_size_ratio=1)
# g.settings.num_plot_contours = 2
g.settings.axes_labelsize = 18
g.settings.axes_fontsize = 16
g.settings.legend_fontsize = 14
g.triangle_plot([gp_samples,true_samples], names,filled=[True,False],contour_colors=['red','blue'],
                                legend_labels=[f'GP fit, N = {gp.train_y.shape[0]} samples','True Distribution'],
                                contour_lws=[1,1.5],markers = dict(zip(names,f_mean)))
# Out:
# Removed no burn in
# Removed no burn in

# %% [markdown]
# ### IPV test

# %%
np.random.seed(10004118) # fixed for reproducibility
# train_x = np.random.uniform(0,1,(12,2))
ninit = 16
ndim = 4
train_x = qmc.Sobol(ndim, scramble=True).random(ninit)
f_mean = np.array([0.41,0.63,0.58,0.45])[:ndim]
cov1 = 0.1*np.eye(ndim) + 0.2*np.random.uniform(0.,0.5,(ndim,ndim))
cov = 0.05*(cov1 + np.transpose(cov1))
print(cov)

from scipy.stats import multivariate_normal

mnorm =  multivariate_normal(mean = f_mean,cov = cov)

f = lambda x: mnorm.logpdf(x).reshape(-1,1) # -0.5*np.sum((x - f_mean)**2,axis=-1,keepdims=True)/ f_std**2 

train_y = f(train_x)
print(train_x.shape,train_y.shape)

train_yvar = 1e-6*jnp.ones_like(train_y)

print("Testing lightweight implementation")

gp = saas_fbgp(train_x,train_y,noise=1e-6)
seed = 0
rng_key, _ = random.split(random.PRNGKey(seed), 2)
gp.fit(rng_key,warmup_steps=512,num_samples=512,thinning=16,verbose=True)

fig,(ax1,ax2) = plt.subplots(1,2,figsize=(12,4))
ax1.scatter(train_x[:,0],train_x[:,1])
ax1.set_xlabel(r'$x_1$')
ax1.set_ylabel(r'$x_2$')
ax2.scatter(train_x[:,2],train_x[:,3])
ax2.set_xlabel(r'$x_3$')
ax2.set_ylabel(r'$x_4$')
# Out:
# [[0.01795472 0.0032797  0.00629377 0.00188088]
#  [0.0032797  0.01140048 0.00206096 0.00450058]
#  [0.00629377 0.00206096 0.0193845  0.00201846]
#  [0.00188088 0.00450058 0.00201846 0.01147207]]
# (16, 4) (16, 1)
# Testing lightweight implementation
# sample: 100%|██████████| 1024/1024 [00:01<00:00, 895.13it/s, 7 steps of size 3.28e-01. acc. prob=0.92]
#                               mean       std    median      5.0%     95.0%     n_eff     r_hat
# _kernel_inv_length_sq[0]      1.71      3.53      0.60      0.04      2.90     37.72      1.03
# _kernel_inv_length_sq[1]      8.52     27.87      2.62      0.89      9.18     35.42      1.00
# _kernel_inv_length_sq[2]      2.30      4.22      1.25      0.07      3.68     32.99      0.99
# _kernel_inv_length_sq[3]      6.13     18.03      2.10      0.38      5.07     34.80      0.99
#         kernel_length[0]      1.89      1.50      1.52      0.15      2.96     35.27      0.98
#         kernel_length[1]      0.75      0.33      0.79      0.11      1.09     40.72      0.99
#         kernel_length[2]      1.24      0.79      1.05      0.31      1.91     32.18      0.99
#         kernel_length[3]      0.85      0.37      0.83      0.47      1.35     28.94      1.03
#             kernel_tausq      1.17      1.64      0.63      0.15      2.16     18.59      1.01
#               kernel_var      9.46      6.87      8.07      0.93     21.79     18.84      1.01
#
# Number of divergences: 0
#
# MCMC elapsed time: 1.29s
# Text(0, 0.5, '$x_4$')

# %%
nsteps = 16 # 32
mc_points_size = 16
start = time.time()
for i in range(nsteps):
    samples, logz_dict = samples, logz_dict = nested_sampling_jaxns(gp,ndim=ndim,dlogz=0.1)
    print(f"LogZ info :"+"".join(f"{key}: = {value:.4f}, " for key, value in logz_dict.items()))
    size = len(samples)
    mc_points = samples[::int(size/mc_points_size),:]
    # print(mc_points.shape)
    acq_func = IPV(gp,mc_points)
    grad_fn = grad(acq_func)
    # print(ndim)
    x0 =  np.random.uniform(0,1,ndim)
    # print(x0.shape)
    results = optim_scipy_bh(acq_func,x0=x0,stepsize=1/4,
                                      niter=15,minimizer_kwargs={'jac': grad_fn, 'bounds': ndim*[(0,1)] })
    # next_val = results.fun 
    print(f"Next point at x = {results.x} with acquisition function value = {results.fun}")
    next_x = jnp.atleast_2d(results.x)
    next_y = f((next_x)) 
    # print(next_y.shape)
    train_x = jnp.concatenate([train_x,next_x])
    train_y = jnp.concatenate([train_y,next_y])
    gp = saas_fbgp(train_x,train_y,noise=1e-6)
    gp.fit(rng_key,warmup_steps=256,num_samples=256,thinning=16,verbose=False) # change rng key?
    print(f"----------------------Step {i+1} complete----------------------\n")


print(f"BO took {time.time() - start:.2f} s ")
# Out:
# Nested Sampling took 2.27s
# jaxns made 24239 likelihood evaluations
# LogZ info :logz_mean: = -0.2710, dlogz: = 0.2580,
# Acquisition optimization took 2.32 s
# Next point at x = [0.06182678 0.58062032 0.43147948 0.55556004] with acquisition function value = 0.03430689796106713
# sample: 100%|██████████| 512/512 [00:00<00:00, 535.89it/s, 7 steps of size 4.28e-01. acc. prob=0.83]
# MCMC elapsed time: 1.10s
# ----------------------Step 1 complete----------------------
#
# Nested Sampling took 2.34s
# jaxns made 27483 likelihood evaluations
# LogZ info :logz_mean: = -0.4867, dlogz: = 0.2603,
# Acquisition optimization took 2.74 s
# Next point at x = [0.41518669 0.61669199 0.58248183 0.43294933] with acquisition function value = 0.008754851887686012
# sample: 100%|██████████| 512/512 [00:00<00:00, 547.35it/s, 7 steps of size 4.89e-01. acc. prob=0.91]
# MCMC elapsed time: 1.26s
# ----------------------Step 2 complete----------------------
#
# Nested Sampling took 2.12s
# jaxns made 28590 likelihood evaluations
# LogZ info :logz_mean: = 0.0678, dlogz: = 0.2618,
# Acquisition optimization took 4.73 s
# Next point at x = [0.41263009 0.64357671 0.62862162 0.46282032] with acquisition function value = 0.0015531740360763425
# sample: 100%|██████████| 512/512 [00:01<00:00, 504.76it/s, 7 steps of size 5.83e-01. acc. prob=0.87]
# MCMC elapsed time: 1.32s
# ----------------------Step 3 complete----------------------
#
# Nested Sampling took 2.18s
# jaxns made 28704 likelihood evaluations
# LogZ info :logz_mean: = 0.1573, dlogz: = 0.2558,
# Acquisition optimization took 2.96 s
# Next point at x = [0.45851286 0.61276641 0.82723844 0.48238404] with acquisition function value = 0.000748263865815767
# sample: 100%|██████████| 512/512 [00:00<00:00, 577.72it/s, 7 steps of size 7.51e-01. acc. prob=0.84]
# MCMC elapsed time: 1.15s
# ----------------------Step 4 complete----------------------
#
# Nested Sampling took 2.14s
# jaxns made 26281 likelihood evaluations
# LogZ info :logz_mean: = 0.1324, dlogz: = 0.2567,
# Acquisition optimization took 3.44 s
# Next point at x = [0.40296162 0.52740441 0.30746631 0.41145533] with acquisition function value = 0.00040978736617761427
# sample: 100%|██████████| 512/512 [00:00<00:00, 607.28it/s, 7 steps of size 6.67e-01. acc. prob=0.90]
# MCMC elapsed time: 1.13s
# ----------------------Step 5 complete----------------------
#
# Nested Sampling took 2.44s
# jaxns made 28893 likelihood evaluations
# LogZ info :logz_mean: = -0.0791, dlogz: = 0.2653,
# Acquisition optimization took 3.64 s
# Next point at x = [0.54185258 0.71431886 0.89790953 0.57445278] with acquisition function value = 0.0002521765147905121
# sample: 100%|██████████| 512/512 [00:00<00:00, 558.07it/s, 7 steps of size 5.97e-01. acc. prob=0.90]
# MCMC elapsed time: 1.21s
# ----------------------Step 6 complete----------------------
#
# Nested Sampling took 2.28s
# jaxns made 25317 likelihood evaluations
# LogZ info :logz_mean: = 0.0280, dlogz: = 0.2576,
# Acquisition optimization took 3.53 s
# Next point at x = [0.37032252 0.47839235 0.77575555 0.43065413] with acquisition function value = 0.0001693351143442802
# sample: 100%|██████████| 512/512 [00:00<00:00, 601.37it/s, 7 steps of size 5.75e-01. acc. prob=0.92]
# MCMC elapsed time: 1.10s
# ----------------------Step 7 complete----------------------
#
# Nested Sampling took 2.11s
# jaxns made 25268 likelihood evaluations
# LogZ info :logz_mean: = 0.0521, dlogz: = 0.2586,
# Acquisition optimization took 2.94 s
# Next point at x = [0.45306345 0.7386221  0.71103172 0.43945795] with acquisition function value = 8.998350277320682e-05
# sample: 100%|██████████| 512/512 [00:00<00:00, 569.93it/s, 7 steps of size 7.43e-01. acc. prob=0.88]
# MCMC elapsed time: 1.15s
# ----------------------Step 8 complete----------------------
#
# Nested Sampling took 2.17s
# jaxns made 24659 likelihood evaluations
# LogZ info :logz_mean: = 0.2177, dlogz: = 0.2539,
# Acquisition optimization took 1.28 s
# Next point at x = [9.53886898e-01 3.60631586e-07 9.85661258e-01 5.08487828e-01] with acquisition function value = 9.893039171896684e-05
# sample: 100%|██████████| 512/512 [00:00<00:00, 556.88it/s, 7 steps of size 5.84e-01. acc. prob=0.93]
# MCMC elapsed time: 1.19s
# ----------------------Step 9 complete----------------------
#
# Nested Sampling took 2.12s
# jaxns made 25453 likelihood evaluations
# LogZ info :logz_mean: = 0.1063, dlogz: = 0.2596,
# Acquisition optimization took 3.19 s
# Next point at x = [0.37296565 0.79230958 0.54347397 0.68103803] with acquisition function value = 6.638764377833728e-05
# sample: 100%|██████████| 512/512 [00:00<00:00, 601.91it/s, 7 steps of size 6.37e-01. acc. prob=0.89]
# MCMC elapsed time: 1.08s
# ----------------------Step 10 complete----------------------
#
# Nested Sampling took 2.18s
# jaxns made 25073 likelihood evaluations
# LogZ info :logz_mean: = 0.0044, dlogz: = 0.2625,
# Acquisition optimization took 2.59 s
# Next point at x = [0.13320679 0.44329139 0.56382191 0.36586418] with acquisition function value = 4.9948930136718694e-05
# sample: 100%|██████████| 512/512 [00:00<00:00, 585.97it/s, 7 steps of size 7.09e-01. acc. prob=0.89]
# MCMC elapsed time: 1.13s
# ----------------------Step 11 complete----------------------
#
# Nested Sampling took 2.18s
# jaxns made 24598 likelihood evaluations
# LogZ info :logz_mean: = -0.0224, dlogz: = 0.2632,
# Acquisition optimization took 1.31 s
# Next point at x = [1.         0.5131568  0.27505014 0.96446533] with acquisition function value = 2.6800304700709543e-05
# sample: 100%|██████████| 512/512 [00:00<00:00, 576.03it/s, 7 steps of size 6.22e-01. acc. prob=0.90]
# MCMC elapsed time: 1.17s
# ----------------------Step 12 complete----------------------
#
# Nested Sampling took 2.20s
# jaxns made 25284 likelihood evaluations
# LogZ info :logz_mean: = 0.0233, dlogz: = 0.2611,
# Acquisition optimization took 1.29 s
# Next point at x = [0.61150089 0.30085927 0.39489431 0.        ] with acquisition function value = 3.6686001725322326e-05
# sample: 100%|██████████| 512/512 [00:00<00:00, 535.85it/s, 7 steps of size 6.00e-01. acc. prob=0.90]
# MCMC elapsed time: 1.22s
# ----------------------Step 13 complete----------------------
#
# Nested Sampling took 2.91s
# jaxns made 28766 likelihood evaluations
# LogZ info :logz_mean: = 0.0330, dlogz: = 0.2602,
# Acquisition optimization took 1.41 s
# Next point at x = [0.44107048 0.14771272 0.63659764 0.04199919] with acquisition function value = 2.36309229425663e-05
# sample: 100%|██████████| 512/512 [00:00<00:00, 546.09it/s, 7 steps of size 6.89e-01. acc. prob=0.87]
# MCMC elapsed time: 1.23s
# ----------------------Step 14 complete----------------------
#
# Nested Sampling took 2.30s
# jaxns made 25114 likelihood evaluations
# LogZ info :logz_mean: = 0.0310, dlogz: = 0.2634,
# Acquisition optimization took 1.41 s
# Next point at x = [0.94275421 0.22215513 0.90207495 0.07422113] with acquisition function value = 1.5172082463710268e-05
# sample: 100%|██████████| 512/512 [00:00<00:00, 555.65it/s, 7 steps of size 7.12e-01. acc. prob=0.89]
# MCMC elapsed time: 1.19s
# ----------------------Step 15 complete----------------------
#
# Nested Sampling took 2.35s
# jaxns made 28741 likelihood evaluations
# LogZ info :logz_mean: = -0.1189, dlogz: = 0.2669,
# Acquisition optimization took 0.94 s
# Next point at x = [0.40675621 0.61412011 0.33076343 0.24681346] with acquisition function value = 9.271314641096096e-06
# sample: 100%|██████████| 512/512 [00:01<00:00, 318.70it/s, 7 steps of size 6.19e-01. acc. prob=0.92]
# MCMC elapsed time: 1.93s
# ----------------------Step 16 complete----------------------
#
# BO took 96.17 s

# %%
fig,ax = plt.subplots(1,int(ndim/2),figsize=(15,4))
for i,x in enumerate(ax):
    x.scatter(samples[:,2*i],samples[:,2*i+1],s=10,label='MC samples',color='C1',alpha=0.2)
    x.scatter(train_x[ninit:,2*i],train_x[ninit:,2*i+1],s=25,label='Bayop samples',color='C0')
    x.scatter(train_x[:ninit,2*i],train_x[:ninit,2*i+1],s=20,label='Sobol',color='C2')
    x.set_ylabel(r'$x_{{%i}}$'%(2*i+2))
    x.set_xlabel(r'$x_{{{}}}$'.format(2*i+1))
    x.axvline(f_mean[2*i],ls='-.',color='k')
    x.axhline(f_mean[2*i + 1],ls='-.',color='k')
ax[0].legend()

# %%
samples, logz_dict = nested_sampling_jaxns(gp,ndim=ndim,dlogz=0.01,num_samples_equal=3000,difficult_model=True)
print(f"LogZ info: "+"".join(f"{key}: = {value:.4f}, " for key, value in logz_dict.items()))
# Out:
# Nested Sampling took 6.71s
# jaxns made 390241 likelihood evaluations
# LogZ logz_mean: -0.0077, dlogz: 0.1468,

# %%
test_samples = np.random.multivariate_normal(mean=f_mean,cov=cov,size=int(1e5))
labels = [r"x_{0}".format(i) for i in range(ndim)]
names = [r"x_{0}".format(i) for i in range(ndim)]
ranges =  np.array(ndim*[[0,1]])
true_samples = MCSamples(samples=test_samples,names=names, labels = labels,ranges=ranges) # a comparison run
gp_samples = MCSamples(samples=samples[::4],names=names, labels = labels,ranges=ranges)
g = plots.get_subplot_plotter(subplot_size=1.5,subplot_size_ratio=1)
# g.settings.num_plot_contours = 2
g.settings.axes_labelsize = 18
g.settings.axes_fontsize = 16
g.settings.legend_fontsize = 14
g.triangle_plot([gp_samples,true_samples], names,filled=[True,False],contour_colors=['red','blue'],
                                legend_labels=[f'GP fit, N = {gp.train_y.shape[0]} samples','True Distribution'],
                                contour_lws=[1,1.5],markers = dict(zip(names,f_mean)))
# Out:
# Removed no burn in
# Removed no burn in

# %%
# next_x = jnp.atleast_2d(next_x)
# print(next_x.shape)

# %%
# acq_func = IPV(gp,mc_points)


# x0 =  np.random.uniform(0,1,ndim)

# acq_func(x0)

# print(x0.shape)

# x0 = jnp.atleast_2d(x0)

# print(x0.shape)

# %%
# print(mc_points.shape,gp.train_x.shape)
# print(jnp.atleast_2d(mc_points).shape)
