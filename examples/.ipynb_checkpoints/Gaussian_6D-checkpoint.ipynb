# %%
import sys
sys.path.append('../')
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from fb_gp import saas_fbgp
import numpy as np
import time
import jax.numpy as jnp
from jax import random,vmap, grad
from jax.lax import while_loop
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from acquisition import EI, IPV, optim_scipy_bh
import scipy.optimize
from scipy.stats import qmc
from jaxns import NestedSampler
import corner
from nested_sampler import nested_sampling_jaxns, nested_sampling_Dy
from getdist import plots,MCSamples,loadMCSamples


matplotlib.rc('font', size=16,family='serif')
matplotlib.rc('legend', fontsize=16)
# Out:
# INFO:jax._src.xla_bridge:Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# INFO:jax._src.xla_bridge:Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/homebrew/Caskroom/miniforge/base/envs/cosmo/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file), '/usr/local/lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache)

# %%
np.random.seed(10004118) # fixed for reproducibility
# train_x = np.random.uniform(0,1,(12,2))
ninit = 16
ndim = 6
train_x = qmc.Sobol(ndim, scramble=True).random(ninit)
f_mean = np.array([0.41,0.63,0.58,0.45,0.33,0.76])[:ndim]
cov1 = 0.1*np.eye(ndim) + 0.2*np.random.uniform(0.,0.5,(ndim,ndim))
cov = 0.05*(cov1 + np.transpose(cov1))
print(cov)

from scipy.stats import multivariate_normal

mnorm =  multivariate_normal(mean = f_mean,cov = cov)

f = lambda x: mnorm.logpdf(x).reshape(-1,1) # -0.5*np.sum((x - f_mean)**2,axis=-1,keepdims=True)/ f_std**2 

train_y = f(train_x)
print(train_x.shape,train_y.shape)

train_yvar = 1e-6*jnp.ones_like(train_y)

print("Testing lightweight implementation")

gp = saas_fbgp(train_x,train_y,noise=1e-6)
seed = 0
rng_key, _ = random.split(random.PRNGKey(seed), 2)
gp.fit(rng_key,warmup_steps=512,num_samples=512,thinning=16,verbose=True)

# fig,(ax1,ax2) = plt.subplots(1,2,figsize=(12,4))
# ax1.scatter(train_x[:,0],train_x[:,1])
# ax1.set_xlabel(r'$x_1$')
# ax1.set_ylabel(r'$x_2$')
# ax2.scatter(train_x[:,2],train_x[:,3])
# ax2.set_xlabel(r'$x_3$')
# ax2.set_ylabel(r'$x_4$')
# Out:
# [[0.01795472 0.00243612 0.00605338 0.00019327 0.00471723 0.00217859]
#  [0.00243612 0.01499472 0.00405332 0.00450817 0.00942717 0.00547193]
#  [0.00605338 0.00405332 0.01039278 0.00441446 0.00710149 0.00406987]
#  [0.00019327 0.00450817 0.00441446 0.01006934 0.00472753 0.00317903]
#  [0.00471723 0.00942717 0.00710149 0.00472753 0.01631171 0.00416325]
#  [0.00217859 0.00547193 0.00406987 0.00317903 0.00416325 0.0109318 ]]
# (16, 6) (16, 1)
# Testing lightweight implementation
# sample: 100%|██████████| 1024/1024 [00:01<00:00, 863.66it/s, 7 steps of size 3.49e-01. acc. prob=0.93]
#                               mean       std    median      5.0%     95.0%     n_eff     r_hat
# _kernel_inv_length_sq[0]      1.38      1.49      0.93      0.00      4.17     44.06      1.06
# _kernel_inv_length_sq[1]      1.58      2.27      0.84      0.01      3.89     36.78      0.97
# _kernel_inv_length_sq[2]     28.70     44.01     11.17      0.30     79.59     36.46      1.00
# _kernel_inv_length_sq[3]      1.47      1.48      1.06      0.03      3.11     31.11      0.97
# _kernel_inv_length_sq[4]      2.63      4.69      0.86      0.23      8.47     46.72      0.98
# _kernel_inv_length_sq[5]      3.16      4.36      1.56      0.07      8.49     29.05      1.04
#         kernel_length[0]      2.83      3.44      1.39      0.34      5.88     35.20      0.97
#         kernel_length[1]      2.54      3.03      1.77      0.16      4.42     25.94      0.97
#         kernel_length[2]      0.45      0.26      0.39      0.16      0.69     33.18      0.97
#         kernel_length[3]      1.73      1.17      1.46      0.32      3.65     53.49      0.97
#         kernel_length[4]      1.61      1.10      1.41      0.29      3.20     25.52      0.98
#         kernel_length[5]      1.50      1.26      0.98      0.14      3.19     16.23      1.00
#             kernel_tausq      1.35      2.66      0.68      0.08      2.23     24.10      0.99
#               kernel_var      5.92      4.51      4.34      0.88     12.30     44.71      0.97
#
# Number of divergences: 0
#
# MCMC elapsed time: 2.70s

# %%
nsteps = 32 # 32
mc_points_size = 16
start = time.time()


ns_skip = 2
fit_skip = 2

for i in range(nsteps):
    if (i%ns_skip==0):
        samples, logz_dict = samples, logz_dict = nested_sampling_jaxns(gp,ndim=ndim,dlogz=0.1)
        print(f"LogZ info :"+"".join(f"{key}: = {value:.4f}, " for key, value in logz_dict.items()))
        size = len(samples)
        mc_points = samples[::int(size/mc_points_size),:]
    acq_func = IPV(gp,mc_points)
    grad_fn = grad(acq_func)
    x0 =  np.random.uniform(0,1,ndim)
    results = optim_scipy_bh(acq_func,x0=x0,stepsize=1/4,
                                      niter=15,minimizer_kwargs={'jac': grad_fn, 'bounds': ndim*[(0,1)] })
    print(f"Next point at x = {results.x} with acquisition function value = {results.fun}")
    next_x = jnp.atleast_2d(results.x)
    next_y = f((next_x)) 
    train_x = jnp.concatenate([train_x,next_x])
    train_y = jnp.concatenate([train_y,next_y])
    seed = i
    rng_key, _ = random.split(random.PRNGKey(seed), 2)
    if (i%fit_skip==0):
        gp = saas_fbgp(train_x,train_y,noise=1e-6)
        gp.fit(rng_key,warmup_steps=256,num_samples=256,thinning=16,verbose=False) # change rng key?
    else:
        gp.quick_update(next_x,next_y)
    print(f"----------------------Step {i+1} complete----------------------\n")


print(f"BO took {time.time() - start:.2f} s ")
# Out:
# Nested Sampling took 3.65s
# jaxns did 49355 likelihood evaluations
# LogZ info :logz_mean: = -8.7539, dlogz: = 0.2615,
# Acquisition optimization took 2.96 s
# Next point at x = [0.79280268 0.60724501 0.64036333 0.11666891 0.17651779 0.76418893] with acquisition function value = 0.11861072259608829
# sample: 100%|██████████| 512/512 [00:00<00:00, 582.52it/s, 15 steps of size 3.42e-01. acc. prob=0.89]
# MCMC elapsed time: 1.32s
# ----------------------Step 1 complete----------------------
#
# Acquisition optimization took 2.96 s
# Next point at x = [0.81072626 0.80013802 0.73134921 0.22714797 0.42524895 0.83995902] with acquisition function value = 0.05763509956078764
# ----------------------Step 2 complete----------------------
#
# Nested Sampling took 2.99s
# jaxns did 50102 likelihood evaluations
# LogZ info :logz_mean: = -7.7799, dlogz: = 0.2692,
# Acquisition optimization took 2.70 s
# Next point at x = [0.90670181 0.69578609 0.45531974 0.05526169 0.1441475  0.33336831] with acquisition function value = 0.07017473061511657
# sample: 100%|██████████| 512/512 [00:00<00:00, 536.11it/s, 7 steps of size 3.95e-01. acc. prob=0.91]
# MCMC elapsed time: 1.33s
# ----------------------Step 3 complete----------------------
#
# Acquisition optimization took 3.20 s
# Next point at x = [0.70247726 0.97770284 0.64496405 0.02958817 0.33837712 0.66350179] with acquisition function value = 0.04963924327628619
# ----------------------Step 4 complete----------------------
#
# Nested Sampling took 3.28s
# jaxns did 60832 likelihood evaluations
# LogZ info :logz_mean: = -2.6787, dlogz: = 0.2919,
# Acquisition optimization took 3.21 s
# Next point at x = [0.91712862 0.2061846  0.71480344 0.15081177 0.23746875 0.99319682] with acquisition function value = 0.04141098511228569
# sample: 100%|██████████| 512/512 [00:00<00:00, 529.22it/s, 15 steps of size 3.35e-01. acc. prob=0.91]
# MCMC elapsed time: 1.35s
# ----------------------Step 5 complete----------------------
#
# Acquisition optimization took 3.64 s
# Next point at x = [0.87215134 0.14792506 0.71259807 0.12449182 0.21249479 0.98281897] with acquisition function value = 0.06012113391095944
# ----------------------Step 6 complete----------------------
#
# Nested Sampling took 2.85s
# jaxns did 68166 likelihood evaluations
# LogZ info :logz_mean: = -7.7687, dlogz: = 0.2762,
# Acquisition optimization took 3.63 s
# Next point at x = [0.70658856 0.73228856 0.71299601 0.33598777 0.49978441 0.8633888 ] with acquisition function value = 0.03985073018972926
# sample: 100%|██████████| 512/512 [00:00<00:00, 576.43it/s, 7 steps of size 4.18e-01. acc. prob=0.85]
# MCMC elapsed time: 1.27s
# ----------------------Step 7 complete----------------------
#
# Acquisition optimization took 3.50 s
# Next point at x = [0.86759936 0.75403219 0.73762467 0.39271672 0.29652242 0.87928053] with acquisition function value = 0.017294079098644728
# ----------------------Step 8 complete----------------------
#
# Nested Sampling took 2.84s
# jaxns did 76585 likelihood evaluations
# LogZ info :logz_mean: = -2.8866, dlogz: = 0.2919,
# Acquisition optimization took 3.76 s
# Next point at x = [0.50641751 0.73822563 0.66781937 0.43791551 0.60467459 0.96111352] with acquisition function value = 0.021481726689710302
# sample: 100%|██████████| 512/512 [00:00<00:00, 550.07it/s, 15 steps of size 4.08e-01. acc. prob=0.89]
# MCMC elapsed time: 1.30s
# ----------------------Step 9 complete----------------------
#
# Acquisition optimization took 4.10 s
# Next point at x = [0.4795256  0.72649227 0.64860596 0.40308541 0.41645919 0.90175261] with acquisition function value = 0.010970262045608489
# ----------------------Step 10 complete----------------------
#
# Nested Sampling took 3.46s
# jaxns did 79399 likelihood evaluations
# LogZ info :logz_mean: = -2.0279, dlogz: = 0.2915,
# Acquisition optimization took 3.47 s
# Next point at x = [0.22412748 0.70718046 0.56858161 0.25761305 0.19241858 0.92396161] with acquisition function value = 0.011888758366832983
# sample: 100%|██████████| 512/512 [00:01<00:00, 508.95it/s, 15 steps of size 2.43e-01. acc. prob=0.96]
# MCMC elapsed time: 1.39s
# ----------------------Step 11 complete----------------------
#
# Acquisition optimization took 3.75 s
# Next point at x = [0.31941829 0.61343945 0.56804838 0.30938654 0.34239045 0.75914914] with acquisition function value = 0.007352861281102964
# ----------------------Step 12 complete----------------------
#
# Nested Sampling took 3.00s
# jaxns did 86909 likelihood evaluations
# LogZ info :logz_mean: = -0.7603, dlogz: = 0.2864,
# Acquisition optimization took 3.83 s
# Next point at x = [0.16151244 0.47098675 0.60977043 0.37802771 0.27244132 0.7074903 ] with acquisition function value = 0.007366155932143967
# sample: 100%|██████████| 512/512 [00:01<00:00, 440.62it/s, 15 steps of size 2.99e-01. acc. prob=0.94]
# MCMC elapsed time: 1.55s
# ----------------------Step 13 complete----------------------
#
# Acquisition optimization took 4.64 s
# Next point at x = [0.39427634 0.53060581 0.61763667 0.35186995 0.41508581 0.83192645] with acquisition function value = 0.004954174408245807
# ----------------------Step 14 complete----------------------
#
# Nested Sampling took 3.17s
# jaxns did 91352 likelihood evaluations
# LogZ info :logz_mean: = -1.6779, dlogz: = 0.2822,
# Acquisition optimization took 5.27 s
# Next point at x = [0.36071841 0.59926722 0.5859577  0.32890572 0.3334021  0.70575811] with acquisition function value = 0.004755083624747535
# sample: 100%|██████████| 512/512 [00:00<00:00, 542.66it/s, 7 steps of size 4.48e-01. acc. prob=0.89]
# MCMC elapsed time: 1.36s
# ----------------------Step 15 complete----------------------
#
# Acquisition optimization took 4.25 s
# Next point at x = [0.25461814 0.61308474 0.62692886 0.49050838 0.28092804 0.86677206] with acquisition function value = 0.0023688132319188357
# ----------------------Step 16 complete----------------------
#
# Nested Sampling took 2.64s
# jaxns did 85412 likelihood evaluations
# LogZ info :logz_mean: = -0.7484, dlogz: = 0.2838,
# Acquisition optimization took 4.14 s
# Next point at x = [0.12431895 0.77954797 0.62211844 0.4646486  0.4062569  0.81627862] with acquisition function value = 0.002350680054207038
# sample: 100%|██████████| 512/512 [00:02<00:00, 224.06it/s, 7 steps of size 4.26e-01. acc. prob=0.83]
# MCMC elapsed time: 2.79s
# ----------------------Step 17 complete----------------------
#
# Acquisition optimization took 5.14 s
# Next point at x = [0.6668468  0.70096807 0.59935459 0.41370066 0.32483398 0.81252111] with acquisition function value = 0.0011276753305390456
# ----------------------Step 18 complete----------------------
#
# Nested Sampling took 2.75s
# jaxns did 88578 likelihood evaluations
# LogZ info :logz_mean: = -1.1077, dlogz: = 0.2799,
# Acquisition optimization took 4.88 s
# Next point at x = [0.4216804  0.56482333 0.65014825 0.5833831  0.29658589 0.74669499] with acquisition function value = 0.0006854546417082164
# sample: 100%|██████████| 512/512 [00:02<00:00, 235.86it/s, 7 steps of size 5.39e-01. acc. prob=0.92]
# MCMC elapsed time: 2.67s
# ----------------------Step 19 complete----------------------
#
# Acquisition optimization took 4.41 s
# Next point at x = [0.4252978  0.58965405 0.52761507 0.25383843 0.34513361 0.66610029] with acquisition function value = 0.0005895080113751585
# ----------------------Step 20 complete----------------------
#
# Nested Sampling took 2.68s
# jaxns did 80352 likelihood evaluations
# LogZ info :logz_mean: = -0.5517, dlogz: = 0.2733,
# Acquisition optimization took 3.88 s
# Next point at x = [0.29854702 0.50868447 0.52419921 0.40130749 0.20174802 0.66614165] with acquisition function value = 0.0018527360563123131
# sample: 100%|██████████| 512/512 [00:02<00:00, 248.88it/s, 7 steps of size 5.73e-01. acc. prob=0.92]
# MCMC elapsed time: 2.56s
# ----------------------Step 21 complete----------------------
#
# Acquisition optimization took 3.14 s
# Next point at x = [0.35338871 0.57471983 0.7674596  0.51203535 0.53466742 0.81341964] with acquisition function value = 0.0008154966362559149
# ----------------------Step 22 complete----------------------
#
# Nested Sampling took 2.96s
# jaxns did 79172 likelihood evaluations
# LogZ info :logz_mean: = -0.3126, dlogz: = 0.2724,
# Acquisition optimization took 4.83 s
# Next point at x = [0.36020217 0.64317855 0.71115882 0.6685925  0.48678852 0.7998655 ] with acquisition function value = 0.0010756546320844287
# sample: 100%|██████████| 512/512 [00:01<00:00, 270.30it/s, 7 steps of size 5.69e-01. acc. prob=0.93]
# MCMC elapsed time: 2.39s
# ----------------------Step 23 complete----------------------
#
# Acquisition optimization took 3.84 s
# Next point at x = [0.33133785 0.4727097  0.47737049 0.23139517 0.16943461 0.71165441] with acquisition function value = 0.0004489026993954176
# ----------------------Step 24 complete----------------------
#
# Nested Sampling took 2.77s
# jaxns did 82295 likelihood evaluations
# LogZ info :logz_mean: = -0.2338, dlogz: = 0.2757,
# Acquisition optimization took 3.59 s
# Next point at x = [0.58926576 0.64374671 0.76124939 0.41086403 0.49735867 0.7397089 ] with acquisition function value = 0.0004264923418606792
# sample: 100%|██████████| 512/512 [00:02<00:00, 229.16it/s, 7 steps of size 5.91e-01. acc. prob=0.90]
# MCMC elapsed time: 2.76s
# ----------------------Step 25 complete----------------------
#
# Acquisition optimization took 2.28 s
# Next point at x = [0.54391609 0.67942336 0.6089852  0.40734374 0.2129928  0.72230965] with acquisition function value = 0.0002629022335989828
# ----------------------Step 26 complete----------------------
#
# Nested Sampling took 2.75s
# jaxns did 82503 likelihood evaluations
# LogZ info :logz_mean: = 0.0942, dlogz: = 0.2690,
# Acquisition optimization took 3.05 s
# Next point at x = [0.39933635 0.30274664 0.3751541  0.0531354  0.08438706 0.48914413] with acquisition function value = 0.0005834352599723008
# sample: 100%|██████████| 512/512 [00:02<00:00, 227.45it/s, 7 steps of size 5.78e-01. acc. prob=0.94]
# MCMC elapsed time: 2.79s
# ----------------------Step 27 complete----------------------
#
# Acquisition optimization took 4.70 s
# Next point at x = [0.27203556 0.92073598 0.70621806 0.65663209 0.42863017 0.96475839] with acquisition function value = 0.0004621035165798121
# ----------------------Step 28 complete----------------------
#
# Nested Sampling took 3.32s
# jaxns did 75465 likelihood evaluations
# LogZ info :logz_mean: = 0.1062, dlogz: = 0.2696,
# Acquisition optimization took 2.96 s
# Next point at x = [0.55893479 0.88374326 0.85653848 0.64750727 0.62843289 0.8314439 ] with acquisition function value = 0.0005966567719560105
# sample: 100%|██████████| 512/512 [00:02<00:00, 203.31it/s, 7 steps of size 7.93e-01. acc. prob=0.87]
# MCMC elapsed time: 3.04s
# ----------------------Step 29 complete----------------------
#
# Acquisition optimization took 1.84 s
# Next point at x = [0.36591065 0.65408429 0.62766938 0.29290574 0.41825339 0.6481752 ] with acquisition function value = 0.00028589562647728106
# ----------------------Step 30 complete----------------------
#
# Nested Sampling took 2.74s
# jaxns did 76617 likelihood evaluations
# LogZ info :logz_mean: = 0.1180, dlogz: = 0.2734,
# Acquisition optimization took 2.03 s
# Next point at x = [0.46670864 0.51807903 0.4856285  0.42640508 0.04130885 0.76978355] with acquisition function value = 0.00027813950315919156
# sample: 100%|██████████| 512/512 [00:02<00:00, 207.58it/s, 7 steps of size 6.53e-01. acc. prob=0.91]
# MCMC elapsed time: 3.02s
# ----------------------Step 31 complete----------------------
#
# Acquisition optimization took 0.89 s
# Next point at x = [0.25689403 0.12930924 0.35818285 0.88352642 0.999993   0.47996083] with acquisition function value = 0.0002930909633480014
# ----------------------Step 32 complete----------------------
#
# BO took 204.59 s

# %%
print(gp.train_x.shape,gp.train_y.shape)
# Out:
# (48, 6) (48, 1)

# %%
fig,ax = plt.subplots(1,int(ndim/2),figsize=(15,4))
for i,x in enumerate(ax):
    x.scatter(samples[:,2*i],samples[:,2*i+1],s=10,label='MC samples',color='C1',alpha=0.2)
    x.scatter(train_x[ninit:,2*i],train_x[ninit:,2*i+1],s=25,label='Bayop samples',color='C0')
    x.scatter(train_x[:ninit,2*i],train_x[:ninit,2*i+1],s=20,label='Sobol',color='C2')
    x.set_ylabel(r'$x_{{%i}}$'%(2*i+2))
    x.set_xlabel(r'$x_{{{}}}$'.format(2*i+1))
    x.axvline(f_mean[2*i],ls='-.',color='k')
    x.axhline(f_mean[2*i + 1],ls='-.',color='k')
ax[0].legend()
fig.tight_layout()

# %%
samples, logz_dict = nested_sampling_jaxns(gp,ndim=ndim,dlogz=0.01,num_samples_equal=3000,difficult_model=True)
print(f"LogZ "+"".join(f"{key}: {value:.4f}, " for key, value in logz_dict.items()))
# Out:
# Nested Sampling took 17.68s
# jaxns did 1037414 likelihood evaluations
# LogZ logz_mean: -0.2846, dlogz: 0.1538,

# %%
test_samples = np.random.multivariate_normal(mean=f_mean,cov=cov,size=int(1e6))
labels = [r"x_{0}".format(i) for i in range(ndim)]
names = [r"x_{0}".format(i) for i in range(ndim)]
ranges =  np.array(ndim*[[0,1]])
true_samples = MCSamples(samples=test_samples,names=names, labels = labels,ranges=ranges) # a comparison run
gp_samples = MCSamples(samples=samples[::2],names=names, labels = labels,ranges=ranges)
g = plots.get_subplot_plotter(subplot_size=1.5,subplot_size_ratio=1)
# g.settings.num_plot_contours = 2
g.settings.axes_labelsize = 18
g.settings.axes_fontsize = 16
g.settings.legend_fontsize = 14
g.settings.title_limit_fontsize = 14
g.triangle_plot([gp_samples,true_samples], names,filled=[True,False],contour_colors=['red','blue'],
                                legend_labels=[f'GP fit, N = {gp.train_y.shape[0]} samples','True Distribution'],
                                contour_lws=[1,1.5],markers = dict(zip(names,f_mean)),
                                marker_args={'lw': 1.25, 'ls': '-', 'color': 'C2'},title_limit=1 ) # type: ignore

for i in range(ndim):
    ax = g.subplots[i,i]
    ax.axvline(f_mean[i], color='C2', ls='-')
# Out:
# Removed no burn in
# Removed no burn in
